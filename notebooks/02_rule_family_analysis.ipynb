# %% [markdown]
# # Rule Family Analysis
#
# 展示 `run_rule_analysis.py` 生成的家族统计与长度变化。

# %%
import pandas as pd

rows = pd.read_csv('../data/processed/family_report/family_rows.csv')
rows['family_tags'].value_counts().head(10)
