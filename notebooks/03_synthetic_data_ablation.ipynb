# %% [markdown]
# # Synthetic Data Ablation
#
# 读取 `run_synth_ablation.py` 输出，检查合成样本家族平衡。

# %%
import json
from pathlib import Path

summary = json.loads(Path('../data/synthetic/synth_summary.json').read_text(encoding='utf-8'))
summary
