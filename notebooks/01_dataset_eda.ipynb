# %% [markdown]
# # Dataset EDA
#
# 读取 `data/processed/parsed_train.jsonl`，查看样本长度、家族分布和 query 结构。

# %%
import pandas as pd

df = pd.read_json('../data/processed/parsed_train.jsonl', lines=True)
df['num_pairs'] = df['train_pairs'].apply(len)
df[['id', 'num_pairs', 'query_input']].head()
